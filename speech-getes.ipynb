# %%
import pygame
from pygame.locals import *
from OpenGL.GL import *
from OpenGL.GLU import *


def draw_cube():
    glBegin(GL_QUADS)
    glVertex3f(-1, -1, -1)
    glVertex3f(1, -1, -1)
    glVertex3f(1, 1, -1)
    glVertex3f(-1, 1, -1)

    glVertex3f(-1, -1, 1)
    glVertex3f(1, -1, 1)
    glVertex3f(1, 1, 1)
    glVertex3f(-1, 1, 1)

    glVertex3f(-1, -1, -1)
    glVertex3f(1, -1, -1)
    glVertex3f(1, -1, 1)
    glVertex3f(-1, -1, 1)

    glVertex3f(-1, 1, -1)
    glVertex3f(1, 1, -1)
    glVertex3f(1, 1, 1)
    glVertex3f(-1, 1, 1)

    glVertex3f(-1, -1, -1)
    glVertex3f(-1, 1, -1)
    glVertex3f(-1, 1, 1)
    glVertex3f(-1, -1, 1)

    glVertex3f(1, -1, -1)
    glVertex3f(1, 1, -1)
    glVertex3f(1, 1, 1)
    glVertex3f(1, -1, 1)
    glEnd()


def draw_avatar(sign_language="thank_you"):
    glTranslatef(0, 0, -5)

    if sign_language == "thank_you":
        # Simulate "thank you" sign language hand movement
        glRotatef(45, 0, 1, 0)

    draw_cube()


def main():
    pygame.init()
    display = (800, 600)
    pygame.display.set_mode(display, DOUBLEBUF | OPENGL)
    gluPerspective(45, (display[0] / display[1]), 0.1, 50.0)

    while True:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                quit()

        glClear(GL_COLOR_BUFFER_BIT | GL_DEPTH_BUFFER_BIT)
        draw_avatar("thank_you")
        pygame.display.flip()
        pygame.time.wait(10)


if "name" == "main":
    main()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import pygame
from pygame.locals import *
from OpenGL.GL import *
from OpenGL.GLU import *


def draw_cube():
    glBegin(GL_QUADS)
    glVertex3f(-1, -1, -1)
    glVertex3f(1, -1, -1)
    glVertex3f(1, 1, -1)
    glVertex3f(-1, 1, -1)

    glVertex3f(-1, -1, 1)
    glVertex3f(1, -1, 1)
    glVertex3f(1, 1, 1)
    glVertex3f(-1, 1, 1)

    glVertex3f(-1, -1, -1)
    glVertex3f(1, -1, -1)
    glVertex3f(1, -1, 1)
    glVertex3f(-1, -1, 1)

    glVertex3f(-1, 1, -1)
    glVertex3f(1, 1, -1)
    glVertex3f(1, 1, 1)
    glVertex3f(-1, 1, 1)

    glVertex3f(-1, -1, -1)
    glVertex3f(-1, 1, -1)
    glVertex3f(-1, 1, 1)
    glVertex3f(-1, -1, 1)

    glVertex3f(1, -1, -1)
    glVertex3f(1, 1, -1)
    glVertex3f(1, 1, 1)
    glVertex3f(1, -1, 1)
    glEnd()


def draw_avatar(sign_language="thank_you"):
    glTranslatef(0, 0, -5)

    if sign_language == "thank_you":
        # Simulate "thank you" sign language hand movement
        glRotatef(45, 0, 1, 0)

    draw_cube()


def main():
    pygame.init()
    display = (800, 600)
    pygame.display.set_mode(display, DOUBLEBUF | OPENGL)
    gluPerspective(45, (display[0] / display[1]), 0.1, 50.0)

    while True:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                quit()

        glClear(GL_COLOR_BUFFER_BIT | GL_DEPTH_BUFFER_BIT)
        draw_avatar("thank_you")
        pygame.display.flip()
        pygame.time.wait(10)
main()
# Out:
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# Cell In[3], line 67
#      65         pygame.display.flip()
#      66         pygame.time.wait(10)
# ---> 67 main()
#
# Cell In[3], line 63, in main()
#      60         pygame.quit()
#      61         quit()
# ---> 63 glClear(GL_COLOR_BUFFER_BIT | GL_DEPTH_BUFFER_BIT)
#      64 draw_avatar("thank_you")
#      65 pygame.display.flip()
#
# File src/errorchecker.pyx:58, in OpenGL_accelerate.errorchecker._ErrorChecker.glCheckError()
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glClear,
# 	cArguments = (16640,)
# )
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# ...

# %%
import cv2
import os
import speech_recognition as sr


def display_images(text_input, image_mapping):
    # dictionary la text_input eruka nu pakanum
    if text_input not in image_mapping:
        print(f"Images for text input '{text_input}' not found.")
        return

    # dictionary la erunthu list ah images vanganum
    image_files = image_mapping[text_input]

    # Display each image in the list
    for image_file in image_files:
        # Construct the full path to the image
        image_path = os.path.join(folder_path, image_file)

        # Read and display the image
        img = cv2.imread(image_path)
        cv2.imshow("Sign_Gesture", img)
        cv2.waitKey(1000)  # Adjust the delay between images (in milliseconds)

    cv2.destroyAllWindows()


if _name_ == "_main_":
    # Replace these values with the actual folder path and image mapping
    folder_path = "E:\\HD\\video\\"

    # Dictionary mapping text inputs to lists of image files
    image_mapping = {
        # images nama estathuku change panikalam
        "hello": ["img1.webp", "img2.png"],
        "goodbye": ["img3.jpg", "img4.png"],
        "smile": ["img5.jpg", "img6.jpeg", "img7.jpg", "img8.jpeg"],
        # Add more mappings as needed
    }

    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Speak:")
        audio = r.listen(source)

    try:
        text = r.recognize_google(audio)
        print("You said:", text)
    except sr.UnknownValueError:
        print("Could not understand audio")
    except sr.RequestError as e:
        print("Request error; {0}".format(e))

    text_input = text  # input("Enter text input: ")
    text_input = text_input.lower()

    display_images(text_input, image_mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 28
#      23         cv2.waitKey(1000)  # Adjust the delay between images (in milliseconds)
#      25     cv2.destroyAllWindows()
# ---> 28 if _name_ == "_main_":
#      29     # Replace these values with the actual folder path and image mapping
#      30     folder_path = "E:\\HD\\video\\"
#      32     # Dictionary mapping text inputs to lists of image files
#
# NameError: name '_name_' is not defined

# %%
import cv2
import os
import speech_recognition as sr
import numpy as np

def display_images_for_keys(keys, image_mapping):
    for key in keys:
        # Ensure key is lowercase for case-insensitive matching
        key = key.lower()

        if key not in image_mapping:
            print(f"Images for key '{key}' not found.")
            continue

        image_files = image_mapping[key]

        for image_file in image_files:
            image_path = os.path.join(folder_path, image_file)

            if not os.path.isfile(image_path):
                print(f"Image file not found: {image_path}")
                continue

            img = cv2.imread(image_path)

            if img is None:
                print(f"Error loading image: {image_path}")
                continue
            cv2.putText(img, f"{key}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
            cv2.imshow("Sign_Gesture", img)
            cv2.waitKey(25)

    cv2.destroyAllWindows()


if __name__ == "__main__":
    folder_path = r"D:\WORKSPACE\projects\Test Latifa\Data"
    actions = np.load(r"D:\WORKSPACE\projects\Test Latifa\actions_all.npy")
    image_mapping = {}
    for i in actions:
        image_mapping[i] = [os.path.join(folder_path,i,f"{i}_{j}.jpg") for j in range(50)]

    # r = sr.Recognizer()
    # with sr.Microphone() as source:
    #     print("Speak:")
    #     audio = r.listen(source)

    # try:
    #     text = r.recognize_google(audio)
    #     print("You said:", text)
    # except sr.UnknownValueError:
    #     print("Could not understand audio")
    # except sr.RequestError as e:
    #     print("Request error; {0}".format(e))

    keys_input = input("Enter key names (comma-separated): ")
    keys = [key.strip() for key in keys_input.split(',')]

    display_images_for_keys(keys, image_mapping)
# Out:
# Images for key 'happy' not found.
# Image file not found: D:\WORKSPACE\projects\Test Latifa\Data\hello\hello_0.jpg
# Image file not found: D:\WORKSPACE\projects\Test Latifa\Data\thanks\thanks_0.jpg

# %%
keys_input = input("Enter key names (comma-separated): ")
keys = [key.strip() for key in keys_input.split(',')]

# %%
keys
# Out:
# ['hello', 'thanks', 'no']

# %%
image_mapping
# Out:
# {'hello': ['D:\\WORKSPACE\\projects\\Test Latifa\\Data\\hello\\hello_0.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\hello\\hello_1.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\hello\\hello_2.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\hello\\hello_3.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\hello\\hello_4.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\hello\\hello_5.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\hello\\hello_6.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\hello\\hello_7.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\hello\\hello_8.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\hello\\hello_9.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\hello\\hello_10.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\hello\\hello_11.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\hello\\hello_12.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\hello\\hello_13.jpg',
# ...

# %%
import numpy as np
s = np.load(r'D:\WORKSPACE\projects\Test Latifa\actions_all.npy')
s
# Out:
# array(['hello', 'thanks'], dtype='<U6')

# %%
cv2.destroyAllWindows()

# %%
import all_actions as aa
import os

# %%
folder_path = r"D:\WORKSPACE\projects\Test Latifa\Data"
actions = aa.load_all_actions() # list of actions
print(actions)
# Out:
# ['404' 'hello' 'listening' 'please' 'sorry' 'thanks' 'you are welcome']

# %%
image_mapping = {}
for i in actions:
    image_mapping[i] = [os.path.join(folder_path, i, f"{i}_{j}.jpg") for j in range(50)]

# %%
image_mapping
# Out:
# {'404': ['D:\\WORKSPACE\\projects\\Test Latifa\\Data\\404\\404_0.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\404\\404_1.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\404\\404_2.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\404\\404_3.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\404\\404_4.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\404\\404_5.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\404\\404_6.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\404\\404_7.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\404\\404_8.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\404\\404_9.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\404\\404_10.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\404\\404_11.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\404\\404_12.jpg',
#   'D:\\WORKSPACE\\projects\\Test Latifa\\Data\\404\\404_13.jpg',
# ...

# %%
from gensim.models import KeyedVectors

# Load the pretrained Word2Vec model
model_path = r"D:\WORKSPACE\projects\Test Latifa\GoogleNews-vectors-negative300.bin"
word2vec_model = KeyedVectors.load_word2vec_format(model_path, binary=True)

# %%
# Find similar words
similar_words = word2vec_model.most_similar('welcome', topn=10)
print("Similar words to 'word':", similar_words)

# Calculate similarity between two words
# similarity = word2vec_model.similarity('hello', 'hi')
# print("Similarity between 'word1' and 'word2':", similarity)
# Out:
# Similar words to 'word': [('welcomed', 0.7077772617340088), ('welcoming', 0.7071465849876404), ('welcomes', 0.6647579669952393), ('warmly_welcomed', 0.6219103932380676), ('warmly_welcome', 0.5892777442932129), ('Welcoming', 0.5658251643180847), ('greatly_appreciated', 0.5299198627471924), ('warmly_welcomes', 0.521955132484436), ('invite', 0.517001211643219), ('delighted', 0.5136862993240356)]

# %%
(similar_words[4][0])
# Out:
# 'warmly_welcome'

# %%
text = input("say : ")
keys = [key.strip() for key in text.split(' ')]

# %%
keys
# Out:
# ['happy', 'morning']
